# %%
# Import SparkSession
from pyspark.sql import SparkSession

# %%
# Create SparkSession 
spark = SparkSession.builder \
      .master("local[1]") \
      .appName("SparkByExamples.com") \
      .getOrCreate()
# Out:
# 24/07/05 17:10:23 WARN Utils: Your hostname, sid-VirtualBox resolves to a loopback address: 127.0.1.1; using 10.0.2.15 instead (on interface enp0s3)
# 24/07/05 17:10:23 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/05 17:10:24 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# Create DataFrame from CSV file
df = spark.read.csv("/home/sid/Desktop/copilot/test.csv", header=True, inferSchema=True)
df.printSchema()
# Out:
# root
#  |-- location: string (nullable = true)
#  |-- index: integer (nullable = true)

# %%
df.show()
# Out:
# +--------+-----+
# |location|index|
# +--------+-----+
# | Toronto|    1|
# |      DC|    2|
# |     Nyc|    3|
# +--------+-----+
# 24/07/06 00:40:58 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 6591021 ms exceeds timeout 120000 ms
# 24/07/06 00:40:59 WARN SparkContext: Killing executors is not supported by current scheduler.
# 24/07/06 00:40:59 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exception thrown in awaitResult:
# 	at org.apache.spark.util.SparkThreadUtils$.awaitResult(SparkThreadUtils.scala:56)
# 	at org.apache.spark.util.ThreadUtils$.awaitResult(ThreadUtils.scala:310)
# 	at org.apache.spark.rpc.RpcTimeout.awaitResult(RpcTimeout.scala:75)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRefByURI(RpcEnv.scala:102)
# 	at org.apache.spark.rpc.RpcEnv.setupEndpointRef(RpcEnv.scala:110)
# 	at org.apache.spark.util.RpcUtils$.makeDriverRef(RpcUtils.scala:36)
# ...
